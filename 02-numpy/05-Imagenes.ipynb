# %%
import numpy as np
from scipy import ndimage
from scipy import misc

# %%
mapache = misc.face()
mapache
# Out:
# array([[[121, 112, 131],
#         [138, 129, 148],
#         [153, 144, 165],
#         ...,
#         [119, 126,  74],
#         [131, 136,  82],
#         [139, 144,  90]],
#
#        [[ 89,  82, 100],
#         [110, 103, 121],
#         [130, 122, 143],
#         ...,
#         [118, 125,  71],
#         [134, 141,  87],
#         [146, 153,  99]],
#
#        [[ 73,  66,  84],
#         [ 94,  87, 105],
#         [115, 108, 126],
#         ...,
#         [117, 126,  71],
#         [133, 142,  87],
#         [144, 153,  98]],
#
#        ...,
#
#        [[ 87, 106,  76],
#         [ 94, 110,  81],
#         [107, 124,  92],
#         ...,
#         [120, 158,  97],
#         [119, 157,  96],
#         [119, 158,  95]],
#
#        [[ 85, 101,  72],
#         [ 95, 111,  82],
#         [112, 127,  96],
#         ...,
#         [121, 157,  96],
#         [120, 156,  94],
#         [120, 156,  94]],
#
#        [[ 85, 101,  74],
#         [ 97, 113,  84],
#         [111, 126,  97],
# ...

# %%
mapache.shape
# Out:
# (768, 1024, 3)

# %%
type(mapache)
# Out:
# numpy.ndarray

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(mapache)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-20c10526b722> in <module>
# ----> 1 plt.imshow(mapache)
#       2 plt.show()
#
# NameError: name 'mapache' is not defined

# %%
# por que es un array de 3 dimensiones
plt.imshow(mapache[::-1])

# %%
array1, array2 = np.split(mapache,2)

# %%
plt.imshow(array1)

# %%
plt.imshow(array2)

# %%
#Voy a reducir la imagenen por que quiero subirla en una pagina web, y no me acepta por su tamanio 
m = mapache[::2,::3]

# %%
plt.imshow(m)

# %%
# voy a realizar un rompecabezas para la creacion de un juego
import random
array1, array2, array3, array4, array5, array6, array7, array8 = np.hsplit(mapache,8)
print(array1.shape)
mp = np.array([array7,array1,array5,array8,array2,array6,array3,array4])
# Out:
# (768, 128, 3)

# %%
mp.reshape(1024, 768, 3)
# Out:
# array([[[ 69,  68,  82],
#         [ 67,  66,  80],
#         [ 62,  64,  77],
#         ...,
#         [ 22,  30,  17],
#         [ 22,  30,  17],
#         [ 22,  30,  17]],
#
#        [[ 57,  56,  70],
#         [ 58,  57,  71],
#         [ 55,  57,  70],
#         ...,
#         [ 18,  30,   8],
#         [ 21,  33,  11],
#         [ 29,  41,  19]],
#
#        [[ 55,  54,  68],
#         [ 52,  51,  65],
#         [ 48,  50,  63],
#         ...,
#         [159, 171, 135],
#         [132, 143, 109],
#         [ 99, 113,  78]],
#
#        ...,
#
#        [[134, 160, 112],
#         [135, 162, 111],
#         [137, 161, 109],
#         ...,
#         [ 94, 137,  81],
#         [ 96, 139,  83],
#         [ 97, 140,  84]],
#
#        [[141, 170, 114],
#         [133, 160, 105],
#         [123, 151,  93],
#         ...,
#         [ 98, 137,  82],
#         [ 98, 137,  82],
#         [ 98, 137,  82]],
#
#        [[135, 167, 104],
#         [133, 165, 102],
#         [132, 162, 102],
# ...

# %%
plt.imshow(mp.reshape(768, 1024, 3))

# %%
plt.imshow(mapache, vmin = 0, vmax = -1)
