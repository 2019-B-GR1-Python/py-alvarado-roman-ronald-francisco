# %%
import numpy as np
from scipy import ndimage
from scipy import misc

# %%
mapache = misc.face()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
fila = []

# %%
rana_pepe = mpimg.imread('pepe.jpg')
plt.imshow(rana_pepe)

# %%
array_n_dimensiones = np.vsplit(rana_pepe,4)
plt.imshow(array_n_dimensiones[0])
print(array_n_dimensiones[0].shape)
# Out:
# (65, 460, 3)

# %%
plt.imshow(array_n_dimensiones[0])
for i in range(0,4):
    print(i)
    fila[i] = np.hsplit(array_n_dimensiones[i],4)
# Out:
# 0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-14-4827e32d6414> in <module>
#       2 for i in range(0,4):
#       3     print(i)
# ----> 4     fila[i] = np.hsplit(array_n_dimensiones[i],4)
#
# IndexError: list assignment index out of range

# %%
plt.imshow(fila[0][1])
array = np.array(fila[i])
print(array.shape)
# Out:
# (4, 192, 256, 3)

# %%
for i in range(0,4):
    for j in range(0,4):
        p = plt.imshow(fila[i][j])
        plt.show(p)

# %%
# Out:
# 4
